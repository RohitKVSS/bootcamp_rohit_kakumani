# %%
import pandas from numpy
# Out:
#   Cell In[1], line 1
#     import pandas from numpy
#                   ^
# SyntaxError: invalid syntax

# %%
from numpy import pandas as pd
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 from numpy import pandas as pd
#
# ImportError: cannot import name 'pandas' from 'numpy' (C:\Users\kvssr\anaconda3\envs\bootcamp_env\lib\site-packages\numpy\__init__.py)

# %%
pip install pandas numpy matplotlib
# Out:
# Collecting pandas
#   Downloading pandas-2.3.1-cp310-cp310-win_amd64.whl.metadata (19 kB)
# Requirement already satisfied: numpy in c:\users\kvssr\anaconda3\envs\bootcamp_env\lib\site-packages (2.2.6)
# Collecting matplotlib
#   Downloading matplotlib-3.10.5-cp310-cp310-win_amd64.whl.metadata (11 kB)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\kvssr\anaconda3\envs\bootcamp_env\lib\site-packages (from pandas) (2.9.0.post0)
# Collecting pytz>=2020.1 (from pandas)
#   Using cached pytz-2025.2-py2.py3-none-any.whl.metadata (22 kB)
# Collecting tzdata>=2022.7 (from pandas)
#   Using cached tzdata-2025.2-py2.py3-none-any.whl.metadata (1.4 kB)
# Collecting contourpy>=1.0.1 (from matplotlib)
#   Downloading contourpy-1.3.2-cp310-cp310-win_amd64.whl.metadata (5.5 kB)
# Collecting cycler>=0.10 (from matplotlib)
#   Using cached cycler-0.12.1-py3-none-any.whl.metadata (3.8 kB)
# Collecting fonttools>=4.22.0 (from matplotlib)
#   Downloading fonttools-4.59.1-cp310-cp310-win_amd64.whl.metadata (111 kB)
# Collecting kiwisolver>=1.3.1 (from matplotlib)
#   Downloading kiwisolver-1.4.9-cp310-cp310-win_amd64.whl.metadata (6.4 kB)
# Requirement already satisfied: packaging>=20.0 in c:\users\kvssr\anaconda3\envs\bootcamp_env\lib\site-packages (from matplotlib) (25.0)
# Collecting pillow>=8 (from matplotlib)
#   Downloading pillow-11.3.0-cp310-cp310-win_amd64.whl.metadata (9.2 kB)
# Collecting pyparsing>=2.3.1 (from matplotlib)
#   Using cached pyparsing-3.2.3-py3-none-any.whl.metadata (5.0 kB)
# Requirement already satisfied: six>=1.5 in c:\users\kvssr\anaconda3\envs\bootcamp_env\lib\site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
# Downloading pandas-2.3.1-cp310-cp310-win_amd64.whl (11.3 MB)
#    ---------------------------------------- 0.0/11.3 MB ? eta -:--:--
#    ---------------------------------------  11.3/11.3 MB 64.0 MB/s eta 0:00:01
#    ---------------------------------------- 11.3/11.3 MB 47.1 MB/s eta 0:00:00
# Downloading matplotlib-3.10.5-cp310-cp310-win_amd64.whl (8.1 MB)
#    ---------------------------------------- 0.0/8.1 MB ? eta -:--:--
#    ---------------------------------------- 8.1/8.1 MB 71.2 MB/s eta 0:00:00
# Downloading contourpy-1.3.2-cp310-cp310-win_amd64.whl (221 kB)
# Using cached cycler-0.12.1-py3-none-any.whl (8.3 kB)
# Downloading fonttools-4.59.1-cp310-cp310-win_amd64.whl (2.3 MB)
#    ---------------------------------------- 0.0/2.3 MB ? eta -:--:--
#    ---------------------------------------- 2.3/2.3 MB 42.5 MB/s eta 0:00:00
# Downloading kiwisolver-1.4.9-cp310-cp310-win_amd64.whl (73 kB)
# Downloading pillow-11.3.0-cp310-cp310-win_amd64.whl (7.0 MB)
#    ---------------------------------------- 0.0/7.0 MB ? eta -:--:--
#    ---------------------------------------- 7.0/7.0 MB 61.7 MB/s eta 0:00:00
# Using cached pyparsing-3.2.3-py3-none-any.whl (111 kB)
# Using cached pytz-2025.2-py2.py3-none-any.whl (509 kB)
# Using cached tzdata-2025.2-py2.py3-none-any.whl (347 kB)
# Installing collected packages: pytz, tzdata, pyparsing, pillow, kiwisolver, fonttools, cycler, contourpy, pandas, matplotlib
#
#    ----------------------------------------  0/10 [pytz]
#    ----------------------------------------  0/10 [pytz]
#    ----------------------------------------  0/10 [pytz]
#    ---- -----------------------------------  1/10 [tzdata]
#    ---- -----------------------------------  1/10 [tzdata]
#    ---- -----------------------------------  1/10 [tzdata]
#    ---- -----------------------------------  1/10 [tzdata]
#    ---- -----------------------------------  1/10 [tzdata]
#    ------------ ---------------------------  3/10 [pillow]
#    ------------ ---------------------------  3/10 [pillow]
#    ------------ ---------------------------  3/10 [pillow]
#    ------------ ---------------------------  3/10 [pillow]
#    ------------ ---------------------------  3/10 [pillow]
#    ------------ ---------------------------  3/10 [pillow]
#    ------------ ---------------------------  3/10 [pillow]
#    ------------ ---------------------------  3/10 [pillow]
#    ------------ ---------------------------  3/10 [pillow]
#    -------------------- -------------------  5/10 [fonttools]
#    -------------------- -------------------  5/10 [fonttools]
#    -------------------- -------------------  5/10 [fonttools]
#    -------------------- -------------------  5/10 [fonttools]
#    -------------------- -------------------  5/10 [fonttools]
#    -------------------- -------------------  5/10 [fonttools]
#    -------------------- -------------------  5/10 [fonttools]
#    -------------------- -------------------  5/10 [fonttools]
#    -------------------- -------------------  5/10 [fonttools]
#    -------------------- -------------------  5/10 [fonttools]
#    -------------------- -------------------  5/10 [fonttools]
#    -------------------- -------------------  5/10 [fonttools]
#    -------------------- -------------------  5/10 [fonttools]
#    -------------------- -------------------  5/10 [fonttools]
#    -------------------- -------------------  5/10 [fonttools]
#    -------------------- -------------------  5/10 [fonttools]
#    -------------------- -------------------  5/10 [fonttools]
#    -------------------- -------------------  5/10 [fonttools]
#    -------------------- -------------------  5/10 [fonttools]
#    -------------------- -------------------  5/10 [fonttools]
#    -------------------- -------------------  5/10 [fonttools]
#    -------------------- -------------------  5/10 [fonttools]
#    -------------------- -------------------  5/10 [fonttools]
#    -------------------- -------------------  5/10 [fonttools]
#    -------------------- -------------------  5/10 [fonttools]
#    -------------------- -------------------  5/10 [fonttools]
#    ---------------------------- -----------  7/10 [contourpy]
#    -------------------------------- -------  8/10 [pandas]
#    -------------------------------- -------  8/10 [pandas]
#    -------------------------------- -------  8/10 [pandas]
#    -------------------------------- -------  8/10 [pandas]
#    -------------------------------- -------  8/10 [pandas]
#    -------------------------------- -------  8/10 [pandas]
#    -------------------------------- -------  8/10 [pandas]
#    -------------------------------- -------  8/10 [pandas]
#    -------------------------------- -------  8/10 [pandas]
#    -------------------------------- -------  8/10 [pandas]
#    -------------------------------- -------  8/10 [pandas]
#    -------------------------------- -------  8/10 [pandas]
#    -------------------------------- -------  8/10 [pandas]
#    -------------------------------- -------  8/10 [pandas]
#    -------------------------------- -------  8/10 [pandas]
#    -------------------------------- -------  8/10 [pandas]
#    -------------------------------- -------  8/10 [pandas]
#    -------------------------------- -------  8/10 [pandas]
#    -------------------------------- -------  8/10 [pandas]
#    -------------------------------- -------  8/10 [pandas]
#    -------------------------------- -------  8/10 [pandas]
#    -------------------------------- -------  8/10 [pandas]
#    -------------------------------- -------  8/10 [pandas]
#    -------------------------------- -------  8/10 [pandas]
#    -------------------------------- -------  8/10 [pandas]
#    -------------------------------- -------  8/10 [pandas]
#    -------------------------------- -------  8/10 [pandas]
#    -------------------------------- -------  8/10 [pandas]
#    -------------------------------- -------  8/10 [pandas]
#    -------------------------------- -------  8/10 [pandas]
#    -------------------------------- -------  8/10 [pandas]
#    -------------------------------- -------  8/10 [pandas]
#    -------------------------------- -------  8/10 [pandas]
#    -------------------------------- -------  8/10 [pandas]
#    -------------------------------- -------  8/10 [pandas]
#    -------------------------------- -------  8/10 [pandas]
#    -------------------------------- -------  8/10 [pandas]
#    -------------------------------- -------  8/10 [pandas]
#    -------------------------------- -------  8/10 [pandas]
#    -------------------------------- -------  8/10 [pandas]
#    -------------------------------- -------  8/10 [pandas]
#    -------------------------------- -------  8/10 [pandas]
#    -------------------------------- -------  8/10 [pandas]
#    -------------------------------- -------  8/10 [pandas]
#    -------------------------------- -------  8/10 [pandas]
#    -------------------------------- -------  8/10 [pandas]
#    -------------------------------- -------  8/10 [pandas]
#    -------------------------------- -------  8/10 [pandas]
#    -------------------------------- -------  8/10 [pandas]
#    -------------------------------- -------  8/10 [pandas]
#    -------------------------------- -------  8/10 [pandas]
#    -------------------------------- -------  8/10 [pandas]
#    -------------------------------- -------  8/10 [pandas]
#    -------------------------------- -------  8/10 [pandas]
#    -------------------------------- -------  8/10 [pandas]
#    -------------------------------- -------  8/10 [pandas]
#    -------------------------------- -------  8/10 [pandas]
#    -------------------------------- -------  8/10 [pandas]
#    -------------------------------- -------  8/10 [pandas]
#    -------------------------------- -------  8/10 [pandas]
#    -------------------------------- -------  8/10 [pandas]
#    -------------------------------- -------  8/10 [pandas]
#    -------------------------------- -------  8/10 [pandas]
#    -------------------------------- -------  8/10 [pandas]
#    -------------------------------- -------  8/10 [pandas]
#    -------------------------------- -------  8/10 [pandas]
#    -------------------------------- -------  8/10 [pandas]
#    -------------------------------- -------  8/10 [pandas]
#    -------------------------------- -------  8/10 [pandas]
#    -------------------------------- -------  8/10 [pandas]
#    -------------------------------- -------  8/10 [pandas]
#    -------------------------------- -------  8/10 [pandas]
#    -------------------------------- -------  8/10 [pandas]
#    -------------------------------- -------  8/10 [pandas]
#    -------------------------------- -------  8/10 [pandas]
#    -------------------------------- -------  8/10 [pandas]
#    -------------------------------- -------  8/10 [pandas]
#    -------------------------------- -------  8/10 [pandas]
#    -------------------------------- -------  8/10 [pandas]
#    -------------------------------- -------  8/10 [pandas]
#    -------------------------------- -------  8/10 [pandas]
#    -------------------------------- -------  8/10 [pandas]
#    -------------------------------- -------  8/10 [pandas]
#    -------------------------------- -------  8/10 [pandas]
#    -------------------------------- -------  8/10 [pandas]
#    -------------------------------- -------  8/10 [pandas]
#    -------------------------------- -------  8/10 [pandas]
#    -------------------------------- -------  8/10 [pandas]
#    -------------------------------- -------  8/10 [pandas]
#    -------------------------------- -------  8/10 [pandas]
#    -------------------------------- -------  8/10 [pandas]
#    -------------------------------- -------  8/10 [pandas]
#    -------------------------------- -------  8/10 [pandas]
#    -------------------------------- -------  8/10 [pandas]
#    -------------------------------- -------  8/10 [pandas]
#    -------------------------------- -------  8/10 [pandas]
#    -------------------------------- -------  8/10 [pandas]
#    -------------------------------- -------  8/10 [pandas]
#    -------------------------------- -------  8/10 [pandas]
#    -------------------------------- -------  8/10 [pandas]
#    -------------------------------- -------  8/10 [pandas]
#    -------------------------------- -------  8/10 [pandas]
#    -------------------------------- -------  8/10 [pandas]
#    -------------------------------- -------  8/10 [pandas]
#    -------------------------------- -------  8/10 [pandas]
#    -------------------------------- -------  8/10 [pandas]
#    -------------------------------- -------  8/10 [pandas]
#    -------------------------------- -------  8/10 [pandas]
#    -------------------------------- -------  8/10 [pandas]
#    -------------------------------- -------  8/10 [pandas]
#    -------------------------------- -------  8/10 [pandas]
#    -------------------------------- -------  8/10 [pandas]
#    -------------------------------- -------  8/10 [pandas]
#    -------------------------------- -------  8/10 [pandas]
#    -------------------------------- -------  8/10 [pandas]
#    -------------------------------- -------  8/10 [pandas]
#    -------------------------------- -------  8/10 [pandas]
#    -------------------------------- -------  8/10 [pandas]
#    -------------------------------- -------  8/10 [pandas]
#    -------------------------------- -------  8/10 [pandas]
#    -------------------------------- -------  8/10 [pandas]
#    -------------------------------- -------  8/10 [pandas]
#    -------------------------------- -------  8/10 [pandas]
#    ------------------------------------ ---  9/10 [matplotlib]
#    ------------------------------------ ---  9/10 [matplotlib]
#    ------------------------------------ ---  9/10 [matplotlib]
#    ------------------------------------ ---  9/10 [matplotlib]
#    ------------------------------------ ---  9/10 [matplotlib]
#    ------------------------------------ ---  9/10 [matplotlib]
#    ------------------------------------ ---  9/10 [matplotlib]
#    ------------------------------------ ---  9/10 [matplotlib]
#    ------------------------------------ ---  9/10 [matplotlib]
#    ------------------------------------ ---  9/10 [matplotlib]
#    ------------------------------------ ---  9/10 [matplotlib]
#    ------------------------------------ ---  9/10 [matplotlib]
#    ------------------------------------ ---  9/10 [matplotlib]
#    ------------------------------------ ---  9/10 [matplotlib]
#    ------------------------------------ ---  9/10 [matplotlib]
#    ------------------------------------ ---  9/10 [matplotlib]
#    ------------------------------------ ---  9/10 [matplotlib]
#    ------------------------------------ ---  9/10 [matplotlib]
#    ------------------------------------ ---  9/10 [matplotlib]
#    ------------------------------------ ---  9/10 [matplotlib]
#    ------------------------------------ ---  9/10 [matplotlib]
#    ------------------------------------ ---  9/10 [matplotlib]
#    ------------------------------------ ---  9/10 [matplotlib]
#    ------------------------------------ ---  9/10 [matplotlib]
#    ------------------------------------ ---  9/10 [matplotlib]
#    ------------------------------------ ---  9/10 [matplotlib]
#    ------------------------------------ ---  9/10 [matplotlib]
#    ------------------------------------ ---  9/10 [matplotlib]
#    ------------------------------------ ---  9/10 [matplotlib]
#    ------------------------------------ ---  9/10 [matplotlib]
#    ------------------------------------ ---  9/10 [matplotlib]
#    ------------------------------------ ---  9/10 [matplotlib]
#    ------------------------------------ ---  9/10 [matplotlib]
#    ------------------------------------ ---  9/10 [matplotlib]
#    ------------------------------------ ---  9/10 [matplotlib]
#    ------------------------------------ ---  9/10 [matplotlib]
#    ------------------------------------ ---  9/10 [matplotlib]
#    ------------------------------------ ---  9/10 [matplotlib]
#    ------------------------------------ ---  9/10 [matplotlib]
#    ---------------------------------------- 10/10 [matplotlib]
#
# Successfully installed contourpy-1.3.2 cycler-0.12.1 fonttools-4.59.1 kiwisolver-1.4.9 matplotlib-3.10.5 pandas-2.3.1 pillow-11.3.0 pyparsing-3.2.3 pytz-2025.2 tzdata-2025.2
# Note: you may need to restart the kernel to use updated packages.

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from IPython.display import display
